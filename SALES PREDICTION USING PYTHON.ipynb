# %% [markdown]
# #                  SALES PREDICTION USING PYTHON

# %% [markdown]
# The task is to predict the sales of company's product

# %% [markdown]
# The company has conducted advertising campaigns and the sales for each campaign is given

# %% [markdown]
# I am going to use Linear Regression for sales prediction and I am also going to give a suggestion of a particular advertising campaign for the company to focus on !

# %% [markdown]
# # IMPORTING NECESSARY LIBRARIES :

# %%
import numpy as np
import pandas as pd

#importing visulaisation libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING THE DATASET

# %%
ad=pd.read_csv("Advertising.csv")
ad
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
ad.shape
# Out:
# (200, 5)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
ad.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
plt.scatter(ad['TV'],ad['Sales'])
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("TV vs Sales")
# Out:
# Text(0.5, 1.0, 'TV vs Sales')

# %%
plt.scatter(ad['Radio'],ad['Sales'])
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Radio vs Sales")
# Out:
# Text(0.5, 1.0, 'Radio vs Sales')

# %%
plt.scatter(ad['Newspaper'],ad['Sales'])
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.title("Newspaper vs Sales")
# Out:
# Text(0.5, 1.0, 'Newspaper vs Sales')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.rcParams['figure.figsize']=(18,4)

plt.subplot(1,3,1)
sns.distplot(ad['TV'],color='green')

plt.subplot(1,3,2)
sns.distplot(ad['Radio'],color='green')

plt.subplot(1,3,3)
sns.distplot(ad['Newspaper'],color='green')
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Density'>

# %%
add=ad.drop(columns=['Unnamed: 0'],axis=1)
add
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.pairplot(add)

# %%
sns.lmplot(data=ad,x='TV',y='Sales').set(title='LM plot of TV vs Sales')

# %%
sns.lmplot(data=ad,x='Radio',y='Sales').set(title='LM plot of Radio vs Sales')

# %%
sns.lmplot(data=ad,x='Newspaper',y='Sales').set(title='LM plot of Newspaper vs Sales')

# %% [markdown]
# The plot for Sales is more Linear for TV campaign and the other campaigns (Radio and Newspaper) have many outliers

# %%
X=ad[['TV','Radio','Newspaper']]
Y=ad['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %% [markdown]
# # MODEL CREATION

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# # MODEL FITTING

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # MODEL PREDICTIONS

# %%
model.score(x_test,y_test)
# Out:
# 0.9224605706201435

# %% [markdown]
# Accuracy is 92%

# %%
Y=model.predict(x_test)

# %%
plt.scatter(y_test,Y)
plt.title("ACTUAL vs PREDICTED VALUES")
plt.xlabel("ACTUAL VALUES")
plt.ylabel("PREDICTED VALUES")
# Out:
# Text(0, 0.5, 'PREDICTED VALUES')

# %% [markdown]
#                                Predicted values are ON PAR with Actual values !

# %% [markdown]
# # OBSERVATIONS :

# %% [markdown]
# It is observed that the advertising campaign in TV,
# has a linear relation with the sales
#
# Hence it is advised that
# the company should focus on the TV advertisments, as they produce more sales outcomes
